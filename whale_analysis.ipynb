# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
# YOUR CODE HERE
whale_df = pd.read_csv(whale_returns_csv)

# %%
# Count nulls
# YOUR CODE HERE
whale_df.isnull()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# ...

# %%
# Drop nulls
# YOUR CODE HERE
whale_df.dropna(inplace=True)
whale_df.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE
algo_df = pd.read_csv(algo_returns_csv)

# %%
# Count nulls
# YOUR CODE HERE
algo_df.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
algo_df.dropna(inplace=True)
algo_df.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
# YOUR CODE HERE
sp500_df = pd.read_csv(sp500_history_csv)
sp500_df.set_index('Date')
sp500_df.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# Check Data Types
# YOUR CODE HERE
sp500_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types
#YOUR CODE HERE
sp500_df['Close'] = sp500_df['Close'].str.replace('$', '')
sp500_df['Close'] = sp500_df['Close'].astype(float)
sp500_df.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# YOUR CODE HERE
daily_returns = sp500_df['Close'].pct_change()
daily_returns.head()
# Out:
# 0         NaN
# 1   -0.008764
# 2   -0.001011
# 3   -0.001577
# 4    0.002279
# Name: Close, dtype: float64

# %%
# Drop nulls
# YOUR CODE HERE
daily_returns.dropna(inplace=True)
daily_returns.head()
# Out:
# 1   -0.008764
# 2   -0.001011
# 3   -0.001577
# 4    0.002279
# 5   -0.000509
# Name: Close, dtype: float64

# %%
# Rename Column
# YOUR CODE HERE
columns = ["Date", "S&P 500"]
daily_returns.columns = columns
daily_returns.head()
# Out:
# 1   -0.008764
# 2   -0.001011
# 3   -0.001577
# 4    0.002279
# 5   -0.000509
# Name: Close, dtype: float64

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
returns_master = pd.concat([whale_df, algo_df, daily_returns], axis="columns", join="inner")
returns_master = returns_master.drop(columns=["Date"])
returns_master.head()
# Out:
#     SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 6                   -0.010263           -0.005341
# 7                    0.004012            0.005163
# 8                    0.008265            0.010272
# 9                   -0.002497           -0.001428
# 10                   0.007901            0.003583
#
#     TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# 6                     -0.012079               -0.009739  0.004062  0.013285
# 7                      0.003312               -0.001147  0.001857  0.008284
# 8                      0.013117                0.010801 -0.005012  0.005668
# 9                     -0.003697               -0.008142  0.004406 -0.000735
# 10                     0.007953                0.008055  0.004760 -0.003761
#
#        Close
# 6   0.000630
# 7  -0.006566
# 8  -0.000038
# 9  -0.003466
# 10  0.006105

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
# YOUR CODE HERE
returns_master.plot(figsize=(10,5))

# %%
# Plot cumulative returns
# YOUR CODE HERE
cumulative_returns = (1 + returns_master).cumprod() - 1
cumulative_returns.plot(figsize=(10,5), title="Cumulative Returns of Whale Investors")

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE
returns_master.boxplot(figsize=(20,5))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE
returns_master_std = returns_master.std()

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
annualized_std = returns_master_std * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.124700
# PAULSON & CO.INC.              0.110926
# TIGER GLOBAL MANAGEMENT LLC    0.172156
# BERKSHIRE HATHAWAY INC         0.203994
# Algo 1                         0.122946
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
# YOUR CODE HERE
returns_master.rolling(window=21).std().plot()

# %%
# Construct a correlation table
# YOUR CODE HERE
correlation_tbl = returns_master.corr()
correlation_tbl
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.700191
# PAULSON & CO.INC.                             0.700191            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561548            0.435163
# BERKSHIRE HATHAWAY INC                        0.754025            0.545549
# Algo 1                                       -0.013205           -0.030506
# Algo 2                                       -0.003091           -0.026532
# Close                                        -0.036216           -0.020471
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561548
# PAULSON & CO.INC.                               0.435163
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424908
# Algo 1                                         -0.014538
# ...

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE

rolling_covariance = returns_master['SOROS FUND MANAGEMENT LLC'].rolling(window=30).cov(returns_master['Close'])
rolling_covariance.plot(figsize=(20, 10), title='Soros Beta vs. S&P 500 Returns')

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
# YOUR CODE HERE
weights = [0.1, 0.2, 0.1, 0.2, 0.2, 0.1, 0.1]

portfolio_returns = returns_master.dot(weights)
portfolio_returns.plot()

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE
sharpe_ratios = (returns_master.mean() * 252) / (annualized_std)
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.367157
# PAULSON & CO.INC.             -0.470044
# TIGER GLOBAL MANAGEMENT LLC   -0.113992
# BERKSHIRE HATHAWAY INC         0.633782
# Algo 1                         1.070733
# Algo 2                         0.804573
# Close                         -0.535728
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe_ratios.plot.bar()

#based on my analysis and understanding our algo stratages out perform both the market and whales.

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
goog_hist_csv = Path("Resources/goog_historical.csv")
goog_hist_csv = pd.read_csv(goog_hist_csv)
goog_hist_csv
# Out:
#     Symbol Trade DATE     NOCP
# 0     GOOG   5/9/2019  1162.38
# 1     GOOG   5/8/2019  1166.27
# 2     GOOG   5/7/2019  1174.10
# 3     GOOG   5/6/2019  1189.39
# 4     GOOG   5/3/2019  1185.40
# ..     ...        ...      ...
# 245   GOOG  5/17/2018  1078.59
# 246   GOOG  5/16/2018  1081.77
# 247   GOOG  5/15/2018  1079.23
# 248   GOOG  5/14/2018  1100.20
# 249   GOOG  5/11/2018  1098.26
#
# [250 rows x 3 columns]

# %%
# Read the second stock
# YOUR CODE HERE
aapl_hist_csv = Path("Resources/aapl_historical.csv")
aapl_hist_csv = pd.read_csv(aapl_hist_csv)
aapl_hist_csv
# Out:
#     Symbol Trade DATE    NOCP
# 0     AAPL   5/9/2019  200.72
# 1     AAPL   5/8/2019  202.90
# 2     AAPL   5/7/2019  202.86
# 3     AAPL   5/6/2019  208.48
# 4     AAPL   5/3/2019  211.75
# ..     ...        ...     ...
# 245   AAPL  5/17/2018  186.99
# 246   AAPL  5/16/2018  188.18
# 247   AAPL  5/15/2018  186.44
# 248   AAPL  5/14/2018  188.15
# 249   AAPL  5/11/2018  188.59
#
# [250 rows x 3 columns]

# %%
# Read the third stock
# YOUR CODE HERE
cost_hist_csv = Path("Resources/cost_historical.csv")
cost_hist_csv = pd.read_csv(cost_hist_csv)
cost_hist_csv
# Out:
#     Symbol Trade DATE    NOCP
# 0     COST   5/9/2019  243.47
# 1     COST   5/8/2019  241.34
# 2     COST   5/7/2019  240.18
# 3     COST   5/6/2019  244.23
# 4     COST   5/3/2019  244.62
# ..     ...        ...     ...
# 245   COST  5/17/2018  199.60
# 246   COST  5/16/2018  198.71
# 247   COST  5/15/2018  195.48
# 248   COST  5/14/2018  195.88
# 249   COST  5/11/2018  195.76
#
# [250 rows x 3 columns]

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
custom_master = pd.concat([goog_hist_csv, aapl_hist_csv, cost_hist_csv], axis="rows", join="inner")
custom_master = custom_master.T.drop_duplicates().T
custom_master.head()
# Out:
#   Symbol Trade DATE     NOCP
# 0   GOOG   5/9/2019  1162.38
# 1   GOOG   5/8/2019  1166.27
# 2   GOOG   5/7/2019   1174.1
# 3   GOOG   5/6/2019  1189.39
# 4   GOOG   5/3/2019   1185.4

# %%
# Pivot so that each column of prices represents a unique symbol
#custom_master.dtypes
custom_master['NOCP'] = custom_master['NOCP'].astype(float)
custom_master.pivot_table(columns='Symbol', values='NOCP', index= 'Trade DATE')
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 1/10/2019   153.80  210.64  1070.33
# 1/11/2019   152.29  210.51  1057.19
# 1/14/2019   150.00  209.00  1044.69
# 1/15/2019   153.07  211.03  1077.15
# 1/16/2019   154.94  210.18  1080.97
# ...            ...     ...      ...
# 9/28/2018   225.74  234.88  1193.47
# 9/4/2018    228.36  234.68  1197.00
# 9/5/2018    226.87  235.61  1186.48
# 9/6/2018    223.10  236.68  1171.44
# 9/7/2018    221.30  241.46  1164.83
#
# [250 rows x 3 columns]

# %%
# Drop Nulls
# YOUR CODE HERE
custom_master.dropna(inplace=True)
custom_master['NOCP'] = custom_master['NOCP'].astype(float)
custom_master.dtypes
# Out:
# Symbol         object
# Trade DATE     object
# NOCP          float64
# dtype: object

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
custom_master_returns = custom_master.dot(weights)
custom_master_returns.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-13029ae3eb8d> in <module>
#       2 weights = [1/3, 1/3, 1/3]
#       3 # YOUR CODE HERE
# ----> 4 custom_master_returns = custom_master.dot(weights)
#       5 custom_master_returns.plot()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dot(self, other)
#    1143             return Series(np.dot(lvals, rvals), index=left.index)
#    1144         elif isinstance(rvals, (np.ndarray, Index)):
# -> 1145             result = np.dot(lvals, rvals)
#    1146             if result.ndim == 2:
#    1147                 return self._constructor(result, index=left.index)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE
#use pd.concat to join all data frames
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500    Custom
# Date
# 2019-04-16  0.002899  0.000509  0.000340
# 2019-04-17 -0.005228 -0.002274  0.009292
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE
#use .dropna

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
#calculated using std
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# Algo 2                         0.139556
# S&P 500                        0.152054
# Custom                         0.211496
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P 500                        0.584820
# Custom                         0.933123
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

# %%
# Create a correlation analysis
# YOUR CODE HERE
# Out:
# <style  type="text/css" >
#     #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col1 {
#             background-color:  #acd666;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col3 {
#             background-color:  #badc66;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col4 {
#             background-color:  #40a066;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col5 {
#             background-color:  #c8e366;
#             color:  #000000;
#         }    #T_85543dfe_953f_11ea_9340_c0b6f9140de7row0_col6 {
#             background-color:  #d3e966;
#             color:  #000000;
# ...

# %%
# Beta
# YOUR CODE HERE
